# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35      NaN  33.6
# 1              1       85             66             29      NaN  26.6
# 2              8      183             64              0      0.0  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27      0.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60              0      0.0  30.1
# 767            1       93             70             31      0.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False     True  False
# 1          False    False          False          False     True  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  765.000000
# mean      3.845052  120.894531      69.105469      20.536458   80.112418
# std       3.369578   31.972618      19.355807      15.952218  115.361294
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   36.000000
# 75%       6.000000  140.250000      80.000000      32.000000  128.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.size
# Out:
# 6912

# %%
print(df['Insulin'].mean())
# Out:
# 80.1124183006536

# %%
df['Insulin'] = df['Insulin'].fillna(80.11) #4. Filling missing values

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    80.11  33.6
# 1              1       85             66             29    80.11  26.6
# 2              8      183             64              0     0.00  23.3
# 3              1       89             66             23    94.00  28.1
# 4              0      137             40             35   168.00  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48   180.00  32.9
# 764            2      122             70             27     0.00  36.8
# 765            5      121             72             23   112.00  26.2
# 766            1      126             60              0     0.00  30.1
# 767            1       93             70             31     0.00  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df['SkinThickness'] = df['SkinThickness'].astype(float) #No.5 Data Formatting

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72           35.0    80.11  33.6
# 1              1       85             66           29.0    80.11  26.6
# 2              8      183             64            0.0     0.00  23.3
# 3              1       89             66           23.0    94.00  28.1
# 4              0      137             40           35.0   168.00  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76           48.0   180.00  32.9
# 764            2      122             70           27.0     0.00  36.8
# 765            5      121             72           23.0   112.00  26.2
# 766            1      126             60            0.0     0.00  30.1
# 767            1       93             70           31.0     0.00  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
for column in df.columns:
    df['Insulin'] = df['Insulin']  / df['Insulin'].abs().max() #No.5 DataNormalisation

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   Insulin   BMI  \
# 0              6      148             72           35.0  0.094693  33.6
# 1              1       85             66           29.0  0.094693  26.6
# 2              8      183             64            0.0  0.000000  23.3
# 3              1       89             66           23.0  0.111111  28.1
# 4              0      137             40           35.0  0.198582  43.1
# ..           ...      ...            ...            ...       ...   ...
# 763           10      101             76           48.0  0.212766  32.9
# 764            2      122             70           27.0  0.000000  36.8
# 765            5      121             72           23.0  0.132388  26.2
# 766            1      126             60            0.0  0.000000  30.1
# 767            1       93             70           31.0  0.000000  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Glucose'] = np.where(df['Glucose'] > 125, 1, df['Glucose'])#N0.6

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   Insulin   BMI  \
# 0              6        1             72           35.0  0.094693  33.6
# 1              1       85             66           29.0  0.094693  26.6
# 2              8        1             64            0.0  0.000000  23.3
# 3              1       89             66           23.0  0.111111  28.1
# 4              0        1             40           35.0  0.198582  43.1
# ..           ...      ...            ...            ...       ...   ...
# 763           10      101             76           48.0  0.212766  32.9
# 764            2      122             70           27.0  0.000000  36.8
# 765            5      121             72           23.0  0.132388  26.2
# 766            1        1             60            0.0  0.000000  30.1
# 767            1       93             70           31.0  0.000000  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Glucose'] = np.where(df['Glucose'] > 1, 0, df['Glucose'])

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   Insulin   BMI  \
# 0              6        1             72           35.0  0.094693  33.6
# 1              1        0             66           29.0  0.094693  26.6
# 2              8        1             64            0.0  0.000000  23.3
# 3              1        0             66           23.0  0.111111  28.1
# 4              0        1             40           35.0  0.198582  43.1
# ..           ...      ...            ...            ...       ...   ...
# 763           10        0             76           48.0  0.212766  32.9
# 764            2        0             70           27.0  0.000000  36.8
# 765            5        0             72           23.0  0.132388  26.2
# 766            1        1             60            0.0  0.000000  30.1
# 767            1        0             70           31.0  0.000000  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...
